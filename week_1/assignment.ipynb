# %% [markdown]
# # WEEK 1 ASSIGNMENT

# %%
import pandas as pd

# %% [markdown]
# ### 1. Load CSV Dataset into Pandas DataFrame

# %%
df = pd.read_csv("C:\\Users\\sebin\\Downloads\\Combined_dataset.csv")

# %% [markdown]
# ### 2. Explore Dataset

# %%
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# ...

# %%
df.tail()
# Out:
#      product_id     title                                product_description  \
# 995    13698258     KREDO  Men FORTE Silver Automatic Skeleton Analogue W...
# 996    16896006     GUESS  Women White Patterned Dial & White Straps Anal...
# 997     1708108  GIORDANO  Women Rose Gold-Toned Mirrored Analogue Watch ...
# 998    19280114  Fastrack  Men Black Brass Dial & Black Stainless Steel S...
# 999    18601682   BOLDFIT                           Purple Textured Yoga Mat
#
#      rating  ratings_count  initial_price  discount   final_price currency  \
# 995     3.5             11          11890      50.0  "₹11,890.00"      INR
# 996     5.0             22           8900      45.0   "₹8,900.00"      INR
# 997     2.8              5           7950      50.0   "₹7,950.00"      INR
# 998     4.3             17           3295      20.0   "₹2,636.00"      INR
# 999     3.8            161            699      31.0     "₹699.00"      INR
#
# ...

# %%
df_shape = df.shape
df_shape
# Out:
# (1000, 24)

# %%
df_columns = df.columns
df_columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='str')

# %%
df_dtypes = df.dtypes
df_dtypes
# Out:
# product_id                  int64
# title                         str
# product_description           str
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                   str
# currency                      str
# images                        str
# delivery_options              str
# product_details               str
# breadcrumbs                   str
# product_specifications        str
# amount_of_stars               str
# what_customers_said           str
# seller_name                   str
# sizes                         str
# videos                        str
# seller_information            str
# variations                    str
# best_offer                    str
# more_offers                   str
# category                      str
# dtype: object

# %% [markdown]
# ### 3. Handle Missing Values

# %% [markdown]
# Checking missing values

# %%
df.isnull().sum()
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64

# %% [markdown]
# Handling missing values

# %% [markdown]
# ###### > Fill missing discount values with 0

# %%
df["discount"] = df["discount"].fillna(0)

# %% [markdown]
# ###### > Fill missing object/text columns with "Not Available"

# %%
object_cols = df.select_dtypes(include=["object"]).columns
for col in object_cols:
    df[col] = df[col].fillna("Not Available")
# Out:
# C:\Users\sebin\AppData\Local\Temp\ipykernel_4336\1736938732.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   object_cols = df.select_dtypes(include=["object"]).columns

# %% [markdown]
# Verify missing values

# %%
df.isnull().sum()
# Out:
# product_id                0
# title                     0
# product_description       0
# rating                    0
# ratings_count             0
# initial_price             0
# discount                  0
# final_price               0
# currency                  0
# images                    0
# delivery_options          0
# product_details           0
# breadcrumbs               0
# product_specifications    0
# amount_of_stars           0
# what_customers_said       0
# seller_name               0
# sizes                     0
# videos                    0
# seller_information        0
# variations                0
# best_offer                0
# more_offers               0
# category                  0
# dtype: int64

# %% [markdown]
# ### 4. Perform Basic Operations

# %% [markdown]
# Filter rows

# %% [markdown]
# ###### > Filter products with discount greater than 50%

# %%
high_discount_products = df[df["discount"] > 50]

high_discount_products.head()
# Out:
#    product_id        title                                product_description  \
# 0     8376765  Lino Perros                     Women Navy Blue Solid Backpack
# 2    17633752        Lavie                     Aries Women Pink Mini Backpack
# 3     1376949       F Gear         Unisex Navy & Grey Printed Burner Backpack
# 6    19851824   AVI Living          Grey Solid 500 GSM Pure Cotton Bath Towel
# 7    18602872      My Room  Yellow & Green Floral 140 TC King Bedsheet wit...
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 6     4.0              5           1399      65.0  "₹1,399.00"      INR
# 7     4.7             10           2999      54.0  "₹2,999.00"      INR
#
#                                               images  ...  \
# ...

# %% [markdown]
# ###### > Filter products from one category

# %%
backpack_products = df[df["category"] == "backpacks"]

backpack_products.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
#
#                                               images  ...  \
# 0  http://assets.myntassets.com/assets/images/837...  ...
# 1  http://assets.myntassets.com/assets/images/913...  ...
# ...

# %% [markdown]
# Select columns

# %%
select_columns = df[
    [
        "product_id",
        "title",
        "rating",
        "initial_price",
        "discount",
        "final_price",
    ]
]

select_columns.head()
# Out:
#    product_id           title  rating  initial_price  discount  final_price
# 0     8376765     Lino Perros     3.8           3995      58.0  "₹3,995.00"
# 1     9136281  Tommy Hilfiger     4.5           2899      35.0  "₹2,899.00"
# 2    17633752           Lavie     4.4           2999      65.0  "₹2,999.00"
# 3     1376949          F Gear     4.4           1675      52.0  "₹1,675.00"
# 4    13939916       MYTRIDENT     4.7           2899      17.0  "₹2,899.00"

# %% [markdown]
# ### 5. Remove Duplicates

# %% [markdown]
# Check duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Remove duplicate rows

# %%
df = df.drop_duplicates()

# %% [markdown]
# ### 6. Create a Derived Column (total_amount)

# %%
df["total_amount"] = df["initial_price"] * df["ratings_count"]
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ... what_customers_said  \
# ...

# %% [markdown]
# ### 7. Save Cleaned Dataset in New CSV File

# %%
df.to_csv("cleaned_shopping_dataset.csv", index=False)
